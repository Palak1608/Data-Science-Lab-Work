# %% [markdown]
# <a href="https://colab.research.google.com/github/Palak1608/Data-Science-Lab-Work/blob/main/Lab6_KNN_Classification/lab6_knn_classification.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Titanic data
# predict whether the person had survived
# classification based problem
# Logistic Regression, Decision Tree, KNN
# Data Preprocessing: missing data has to be imputed
# Standardscalar

# %%
### Data analysis
import numpy as np
import pandas as pd

### Visualisation
import matplotlib.pyplot as plt

### Standardscalar
from sklearn.preprocessing import StandardScaler

### KNN
from sklearn.neighbors import KNeighborsClassifier

### Performance metrics
from sklearn.metrics import confusion_matrix, accuracy_score, precision_score, classification_report

# %%
### Load the data
df_train = pd.read_csv('train_KNN.csv')
df_test = pd.read_csv('test_KNN.csv')

# %%
df_test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 418 entries, 0 to 417
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  418 non-null    int64
#  1   Survived     418 non-null    int64
#  2   Pclass       418 non-null    int64
#  3   Name         418 non-null    object
#  4   Sex          418 non-null    object
#  5   Age          332 non-null    float64
#  6   SibSp        418 non-null    int64
#  7   Parch        418 non-null    int64
#  8   Ticket       418 non-null    object
#  9   Fare         417 non-null    float64
#  10  Cabin        91 non-null     object
#  11  Embarked     418 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 39.3+ KB

# %%
df_train.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
mp = 100*(df_train.isnull().sum()/len(df_train))
mp
# Out:
# PassengerId     0.000000
# Survived        0.000000
# Pclass          0.000000
# Name            0.000000
# Sex             0.000000
# Age            19.865320
# SibSp           0.000000
# Parch           0.000000
# Ticket          0.000000
# Fare            0.000000
# Cabin          77.104377
# Embarked        0.224467
# dtype: float64

# %%
mp = mp[mp>0].sort_values()
mp
# Out:
# Embarked     0.224467
# Age         19.865320
# Cabin       77.104377
# dtype: float64

# %%
df_train["Age"].median()
# Out:
# 28.0

# %%
df_train["Fare"].median()
# Out:
# 14.4542

# %%
df_train[df_train["Embarked"].isnull()]
# Out:
#      PassengerId  Survived  Pclass                                       Name  \
# 61            62         1       1                        Icard, Miss. Amelie
# 829          830         1       1  Stone, Mrs. George Nelson (Martha Evelyn)
#
#         Sex   Age  SibSp  Parch  Ticket  Fare Cabin Embarked
# 61   female  38.0      0      0  113572  80.0   B28      NaN
# 829  female  62.0      0      0  113572  80.0   B28      NaN

# %%
df_train = df_train.dropna(axis = 0, subset = ["Embarked"])

# %%
df_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 889 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  889 non-null    int64
#  1   Survived     889 non-null    int64
#  2   Pclass       889 non-null    int64
#  3   Name         889 non-null    object
#  4   Sex          889 non-null    object
#  5   Age          712 non-null    float64
#  6   SibSp        889 non-null    int64
#  7   Parch        889 non-null    int64
#  8   Ticket       889 non-null    object
#  9   Fare         889 non-null    float64
#  10  Cabin        202 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 90.3+ KB

# %%
df_train["Age"] = df_train["Age"].fillna(df_train["Age"].median())

# %%
df_train = df_train.drop(["Cabin"], axis = 1, errors="ignore")  ##1 is for column

# %%
### Testing

# %%
mpt = 100*(df_test.isnull().sum()/len(df_test))
mpt
# Out:
# PassengerId     0.000000
# Survived        0.000000
# Pclass          0.000000
# Name            0.000000
# Sex             0.000000
# Age            20.574163
# SibSp           0.000000
# Parch           0.000000
# Ticket          0.000000
# Fare            0.239234
# Cabin          78.229665
# Embarked        0.000000
# dtype: float64

# %%
mpt = mpt[mpt>0].sort_values()
mpt
# Out:
# Fare      0.239234
# Age      20.574163
# Cabin    78.229665
# dtype: float64

# %%
df_test[df_test["Fare"].isnull()]
# Out:
#      PassengerId  Survived  Pclass                Name   Sex   Age  SibSp  \
# 152         1044         0       3  Storey, Mr. Thomas  male  60.5      0
#
#      Parch Ticket  Fare Cabin Embarked
# 152      0   3701   NaN   NaN        S

# %%
df_test = df_test.dropna(axis = 0, subset = ["Fare"])

# %%
df_test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 417 entries, 0 to 417
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  417 non-null    int64
#  1   Survived     417 non-null    int64
#  2   Pclass       417 non-null    int64
#  3   Name         417 non-null    object
#  4   Sex          417 non-null    object
#  5   Age          331 non-null    float64
#  6   SibSp        417 non-null    int64
#  7   Parch        417 non-null    int64
#  8   Ticket       417 non-null    object
#  9   Fare         417 non-null    float64
#  10  Cabin        91 non-null     object
#  11  Embarked     417 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 42.4+ KB

# %%
df_test["Age"] = df_test["Age"].fillna(df_train["Age"].median())

# %%
df_test = df_test.drop(["Cabin"], axis = 1, errors = "ignore")  ##1 is for column

# %%
df_train.drop(["PassengerId", "Name", "Ticket" ], axis = 1 , inplace = True, errors ="ignore")

# %%
df_test.drop(["PassengerId", "Name", "Ticket" ], axis = 1 , inplace = True, errors ="ignore")

# %%
df_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 889 entries, 0 to 890
# Data columns (total 8 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Survived  889 non-null    int64
#  1   Pclass    889 non-null    int64
#  2   Sex       889 non-null    object
#  3   Age       889 non-null    float64
#  4   SibSp     889 non-null    int64
#  5   Parch     889 non-null    int64
#  6   Fare      889 non-null    float64
#  7   Embarked  889 non-null    object
# dtypes: float64(2), int64(4), object(2)
# memory usage: 62.5+ KB

# %%
df_test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 417 entries, 0 to 417
# Data columns (total 8 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Survived  417 non-null    int64
#  1   Pclass    417 non-null    int64
#  2   Sex       417 non-null    object
#  3   Age       417 non-null    float64
#  4   SibSp     417 non-null    int64
#  5   Parch     417 non-null    int64
#  6   Fare      417 non-null    float64
#  7   Embarked  417 non-null    object
# dtypes: float64(2), int64(4), object(2)
# memory usage: 29.3+ KB

# %%
df_train["Survived"] = df_train["Survived"].apply(str)

# %%
df_train["Pclass"] = df_train["Pclass"].apply(str)

# %%
df_test["Survived"] = df_test["Survived"].apply(str)
df_test["Pclass"] = df_test["Pclass"].apply(str)

# %%
df_train_num = df_train.select_dtypes(exclude = "object")
df_train_obj = df_train.select_dtypes(include = "object")

# %%
df_test_num = df_test.select_dtypes(exclude = "object")
df_test_obj = df_test.select_dtypes(include = "object")

# %%
df_train_num.columns
# Out:
# Index(['Age', 'SibSp', 'Parch', 'Fare'], dtype='object')

# %%
### Dummification of the data

df_train_obj = pd.get_dummies(df_train_obj, drop_first = True)
df_test_obj = pd.get_dummies(df_test_obj, drop_first = True)

# %%
df_test_obj.columns
# Out:
# Index(['Survived_1', 'Pclass_2', 'Pclass_3', 'Sex_male', 'Embarked_Q',
#        'Embarked_S'],
#       dtype='object')

# %%
### Final processed data set

Final_train_df = pd.concat([df_train_num,df_train_obj,df_train["Survived"]],axis= 1)
Final_train_df.head()
# Out:
#     Age  SibSp  Parch     Fare  Survived_1  Pclass_2  Pclass_3  Sex_male  \
# 0  22.0      1      0   7.2500       False     False      True      True
# 1  38.0      1      0  71.2833        True     False     False     False
# 2  26.0      0      0   7.9250        True     False      True     False
# 3  35.0      1      0  53.1000        True     False     False     False
# 4  35.0      0      0   8.0500       False     False      True      True
#
#    Embarked_Q  Embarked_S Survived
# 0       False        True        0
# 1       False       False        1
# 2       False        True        1
# 3       False        True        1
# 4       False        True        0

# %%
### Final processed data set

Final_test_df = pd.concat([df_test_num,df_test_obj,df_test["Survived"]],axis = 1)
Final_test_df.head()
# Out:
#     Age  SibSp  Parch     Fare  Survived_1  Pclass_2  Pclass_3  Sex_male  \
# 0  34.5      0      0   7.8292       False     False      True      True
# 1  47.0      1      0   7.0000        True     False      True     False
# 2  62.0      0      0   9.6875       False      True     False      True
# 3  27.0      0      0   8.6625       False     False      True      True
# 4  22.0      1      1  12.2875        True     False      True     False
#
#    Embarked_Q  Embarked_S Survived
# 0        True       False        0
# 1       False        True        1
# 2        True       False        0
# 3       False        True        0
# 4       False        True        1

# %%
### Standardised the data
### define Xtrain, Y train

X_train = Final_train_df.drop(["Survived"], axis = 1)

# %%
y_train = Final_train_df["Survived"]

# %%
y_test = Final_test_df["Survived"]

# %%
X_test = Final_test_df.drop(["Survived"], axis = 1)

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()

scaled_X_train = scaler.fit_transform(X_train)
scaled_X_test = scaler.transform(X_test)

# %%
### Use the model
from sklearn.neighbors import KNeighborsClassifier

knn = KNeighborsClassifier(n_neighbors=5)

knn.fit(scaled_X_train, y_train)

y_pred = knn.predict(scaled_X_test)

from sklearn.metrics import accuracy_score

accuracy_score(y_test, y_pred)
# Out:
# 0.9928057553956835

# %%
knn.fit(scaled_X_train, y_train)
print(knn)
# Out:
# KNeighborsClassifier()

# %%
y_pred = knn.predict(scaled_X_test)

# %%
accuracy_score(y_test, y_pred)
# Out:
# 0.9928057553956835

# %%
### for different values of k we are going to check
Performance_Metrics = []
for k in range(1,30):
  knn_k = KNeighborsClassifier(n_neighbors=k)
  knn_k.fit(scaled_X_train, y_train)
  y_pred_k = knn_k.predict(scaled_X_test)
  accuracy_k = 1-accuracy_score(y_test, y_pred_k)
  Performance_Metrics.append(accuracy_k)

# %%
Performance_Metrics
# Out:
# [0.007194244604316502,
#  0.00959232613908878,
#  0.00959232613908878,
#  0.007194244604316502,
#  0.007194244604316502,
#  0.00959232613908878,
#  0.00959232613908878,
#  0.011990407673860948,
#  0.014388489208633115,
#  0.011990407673860948,
#  0.011990407673860948,
#  0.011990407673860948,
#  0.00959232613908878,
#  0.00959232613908878,
#  0.00959232613908878,
#  0.011990407673860948,
#  0.00959232613908878,
#  0.011990407673860948,
#  0.011990407673860948,
#  0.011990407673860948,
#  0.011990407673860948,
#  0.011990407673860948,
#  0.011990407673860948,
#  0.011990407673860948,
#  0.014388489208633115,
#  0.014388489208633115,
#  0.00959232613908878,
#  0.011990407673860948,
#  0.011990407673860948]

# %%
plt.plot(range(1,30), Performance_Metrics)

# %%
### Decision tree

from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score

dt = DecisionTreeClassifier()

dt.fit(scaled_X_train, y_train)

y_pred_dt = dt.predict(scaled_X_test)

accuracy_score(y_test, y_pred_dt)
# Out:
# 1.0

# %%
### Classification report

print(classification_report(y_test, y_pred_dt))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00       265
#            1       1.00      1.00      1.00       152
#
#     accuracy                           1.00       417
#    macro avg       1.00      1.00      1.00       417
# weighted avg       1.00      1.00      1.00       417

# %%
### Logistic regression

from sklearn.linear_model import LogisticRegression

lr = LogisticRegression()

lr.fit(scaled_X_train, y_train)

y_pred_lr = lr.predict(scaled_X_test)

accuracy_score(y_test, y_pred_lr)
# Out:
# 1.0

# %%
### Classification report

from sklearn.metrics import classification_report

print(classification_report(y_test, y_pred_lr))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00       265
#            1       1.00      1.00      1.00       152
#
#     accuracy                           1.00       417
#    macro avg       1.00      1.00      1.00       417
# weighted avg       1.00      1.00      1.00       417

# %%
from sklearn.metrics import accuracy_score

accuracy_knn = accuracy_score(y_test, y_pred)
accuracy_lr = accuracy_score(y_test, y_pred_lr)
accuracy_dt = accuracy_score(y_test, y_pred_dt)

# %%
print("KNN Accuracy:", accuracy_knn)
print("Logistic Regression Accuracy:", accuracy_lr)
print("Decision Tree Accuracy:", accuracy_dt)
# Out:
# KNN Accuracy: 0.9928057553956835
# Logistic Regression Accuracy: 1.0
# Decision Tree Accuracy: 1.0

# %%
import matplotlib.pyplot as plt

models = ['KNN', 'Logistic Regression', 'Decision Tree']
accuracies = [accuracy_knn, accuracy_lr, accuracy_dt]

plt.figure(figsize=(6,4))
plt.bar(models, accuracies)
plt.ylabel("Accuracy")
plt.title("Model Accuracy Comparison")
plt.ylim(0.98,1.01)
plt.show()

# %% [markdown]
# ### Interpretation of results
#
# Three machine learning models were applied to the Titanic dataset: KNN, Logistic Regression, and Decision Tree. The KNN model achieved an accuracy of about **0.9928**, while Logistic Regression and Decision Tree both achieved an accuracy of **1.0** on the test data.
#
# This shows that all three models performed very well, likely because the dataset contains features such as passenger class, gender, and age that strongly relate to survival. Overall, the results demonstrate how different machine learning models can be trained and compared on the same dataset.
