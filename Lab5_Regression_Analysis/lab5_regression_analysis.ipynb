# %% [markdown]
# <a href="https://colab.research.google.com/github/Palak1608/Data-Science-Lab-Work/blob/main/Lab5_Regression_Analysis/lab5_regression_analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Step 1: Import the libraries
# Step 2: Load the data
# Step 3: Data exploration
# Step 4: Data visualization
# Step 5: Divide the data into training and testing
# Step 6: Apply machine learning algorithms

# %%
### step 1:import the require libraries

import numpy as np
import  pandas as pd
import matplotlib.pyplot as  plt
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# # Step 2: load the data
# CRIM: per capita crime rate by town
#
# ZN: proportion of residential land zoned for lots over 25,000 sq.ft.
#
# INDUS: proportion of non-retail business acres per town
#
# CHAS: Charles River dummy variable (1 if tract bounds river; 0 otherwise)
#
# NOX: nitric oxides concentration (parts per 10 million)
#
# RM: average number of rooms per dwelling
#
# AGE: proportion of owner-occupied units built prior to 1940
#
# DIS: weighted distances to five Boston employment centres
#
# RAD: index of accessibility to radial highways
#
# TAX: full-value property-tax rate per ($10,000)
#
# PTRATIO: pupil-teacher ratio by town
#
# B: 1000(Bk - 0.63)^2 where Bk is the proportion of [people of African American descent] by town
#
# LSTAT: % lower status of the population
#
# MEDV: Median value of owner-occupied homes in $1000s (target variable)

# %%
# Step 2: Load the data
import pandas as pd

mydata = pd.read_csv("Boston_HousingDataSet.xls")

mydata.head(20)
# Out:
#        CRIM    ZN  INDUS  CHAS     NX     RM    AGE     DIS  RAD  TAX  \
# 0   0.00632  18.0   2.31     0  0.538  6.575   65.2  4.0900    1  296
# 1   0.02731   0.0   7.07     0  0.469  6.421   78.9  4.9671    2  242
# 2   0.02729   0.0   7.07     0  0.469  7.185   61.1  4.9671    2  242
# 3   0.03237   0.0   2.18     0  0.458  6.998   45.8  6.0622    3  222
# 4   0.06905   0.0   2.18     0  0.458  7.147   54.2  6.0622    3  222
# 5   0.02985   0.0   2.18     0  0.458  6.430   58.7  6.0622    3  222
# 6   0.08829  12.5   7.87     0  0.524  6.012   66.6  5.5605    5  311
# 7   0.14455  12.5   7.87     0  0.524  6.172   96.1  5.9505    5  311
# 8   0.21124  12.5   7.87     0  0.524  5.631  100.0  6.0821    5  311
# 9   0.17004  12.5   7.87     0  0.524  6.004   85.9  6.5921    5  311
# 10  0.22489  12.5   7.87     0  0.524  6.377   94.3  6.3467    5  311
# 11  0.11747  12.5   7.87     0  0.524  6.009   82.9  6.2267    5  311
# ...

# %%
# Model
mydata.describe()
# Out:
#              CRIM          ZN       INDUS        CHAS          NX          RM  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean     3.613524   11.363636   11.136779    0.069170    0.554695    6.284634
# std      8.601545   23.322453    6.860353    0.253994    0.115878    0.702617
# min      0.006320    0.000000    0.460000    0.000000    0.385000    3.561000
# 25%      0.082045    0.000000    5.190000    0.000000    0.449000    5.885500
# 50%      0.256510    0.000000    9.690000    0.000000    0.538000    6.208500
# 75%      3.677083   12.500000   18.100000    0.000000    0.624000    6.623500
# max     88.976200  100.000000   27.740000    1.000000    0.871000    8.780000
#
#               AGE         DIS         RAD         TAX     PTRATIO           B  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean    68.574901    3.795043    9.549407  408.237154   18.455534  356.674032
# ...

# %%
# Plot histogram for house price distribution
import seaborn as sns
import matplotlib.pyplot as plt

sns.histplot(mydata["MEDV"], bins=15, color="pink")
plt.title("Histogram of MEDV")
plt.xlabel("MEDV")
plt.ylabel("Frequency")
plt.show()

# %%
# Plot box plot for AGE distribution
# Plot box plot for house price distribution
sns.boxplot(mydata["MEDV"])

plt.title("Median value of owner-occupied homes in $1000s")
plt.xlabel("MEDV")
plt.ylabel("Price in $1000s")

plt.show()

# %%
# Plot box plot for AGE distribution
import seaborn as sns
import matplotlib.pyplot as plt

sns.boxplot(y=mydata["AGE"])

plt.title("Distribution of AGE")
plt.ylabel("AGE (Proportion of houses built before 1940)")
plt.show()

# %%
# Plot scatter graph for AGE vs house price
sns.scatterplot(x="AGE", y="MEDV", data=mydata, color="pink", alpha=0.8)

plt.title("Age of the Building vs Price")
plt.xlabel("Age of the building")
plt.ylabel("Housing Price")

plt.show()

# %%
# Plot scatter graph for RM vs house price
import seaborn as sns
import matplotlib.pyplot as plt

sns.scatterplot(x="RM", y="MEDV", data=mydata, color="purple", alpha=0.7)

plt.title("Average Rooms vs House Price")
plt.xlabel("Average Number of Rooms (RM)")
plt.ylabel("House Price (MEDV in $1000s)")
plt.show()

# %%
# Plot scatter graph for crime rate vs house price
import seaborn as sns
import matplotlib.pyplot as plt

sns.scatterplot(x="CRIM", y="MEDV", data=mydata, color="skyblue", alpha=0.7)

plt.title("Crime Rate vs House Price")
plt.xlabel("Crime Rate (CRIM)")
plt.ylabel("House Price (MEDV in $1000s)")
plt.show()

# %%
# Calculate average house price for each RAD value
rad_medv_mean = mydata.groupby("RAD")["MEDV"].mean()
rad_medv_mean
# Out:
# RAD
# 1     24.365000
# 2     26.833333
# 3     27.928947
# 4     21.387273
# 5     25.706957
# 6     20.976923
# 7     27.105882
# 8     30.358333
# 24    16.403788
# Name: MEDV, dtype: float64

# %%
# Plot bar graph for RAD vs MEDV
import seaborn as sns
import matplotlib.pyplot as plt

sns.barplot(x="RAD", y="MEDV", data=mydata)

plt.title("Highway Accessibility (RAD) vs House Price")
plt.xlabel("RAD (Highway Accessibility Index)")
plt.ylabel("Average House Price (MEDV)")
plt.show()

# %%
# Compute correlation between all features
corr_matrix = mydata.corr()
corr_matrix
# Out:
#              CRIM        ZN     INDUS      CHAS        NX        RM       AGE  \
# CRIM     1.000000 -0.200469  0.406583 -0.055892  0.420972 -0.219247  0.352734
# ZN      -0.200469  1.000000 -0.533828 -0.042697 -0.516604  0.311991 -0.569537
# INDUS    0.406583 -0.533828  1.000000  0.062938  0.763651 -0.391676  0.644779
# CHAS    -0.055892 -0.042697  0.062938  1.000000  0.091203  0.091251  0.086518
# NX       0.420972 -0.516604  0.763651  0.091203  1.000000 -0.302188  0.731470
# RM      -0.219247  0.311991 -0.391676  0.091251 -0.302188  1.000000 -0.240265
# AGE      0.352734 -0.569537  0.644779  0.086518  0.731470 -0.240265  1.000000
# DIS     -0.379670  0.664408 -0.708027 -0.099176 -0.769230  0.205246 -0.747881
# RAD      0.625505 -0.311948  0.595129 -0.007368  0.611441 -0.209847  0.456022
# TAX      0.582764 -0.314563  0.720760 -0.035587  0.668023 -0.292048  0.506456
# PTRATIO  0.289946 -0.391679  0.383248 -0.121515  0.188933 -0.355501  0.261515
# ...

# %%
# Plot correlation heatmap
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(10,8))

sns.heatmap(corr_matrix,
            annot=True,        # show numbers
            cmap="cool",   # color style
            fmt=".2f")

plt.title("Correlation Heatmap")
plt.show()

# %%
# Prepare features and split dataset into train and test
from sklearn.model_selection import train_test_split

X = mydata.drop(columns=["MEDV"])
y = mydata["MEDV"]

X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.3, random_state=42
)

# %%
# Initialize and train Linear Regression model
from sklearn.linear_model import LinearRegression

lr = LinearRegression()
lr_model = lr.fit(X_train, y_train)

# %%
# Calculate performance of Linear Regression model
from sklearn.metrics import r2_score, mean_squared_error

y_pred = lr_model.predict(X_test)

print("R2 Score:", r2_score(y_test, y_pred))
print("MSE:", mean_squared_error(y_test, y_pred))
# Out:
# R2 Score: 0.711226005748492
# MSE: 21.517444231177297

# %%
# Decision Tree model training and evaluation
from sklearn.tree import DecisionTreeRegressor
from sklearn.metrics import mean_squared_error, r2_score
import numpy as np

# Create model
dtr = DecisionTreeRegressor(random_state=42)

# Train model
dtr_model = dtr.fit(X_train, y_train)

# Predict
y_pred_dtr = dtr_model.predict(X_test)

# Evaluate
mse_dtr = mean_squared_error(y_test, y_pred_dtr)
rmse_dtr = np.sqrt(mse_dtr)
r2_dtr = r2_score(y_test, y_pred_dtr)

print("RMSE:", rmse_dtr)
print("R2 Score:", r2_dtr)
# Out:
# RMSE: 3.404119021977562
# R2 Score: 0.8444833592340152

# %%
from sklearn.metrics import mean_squared_error, mean_absolute_percentage_error
import numpy as np

# %%
# Predict using Linear Regression
y_pred_lr = lr_model.predict(X_test)

mse_lr = mean_squared_error(y_test, y_pred_lr)
mape_lr = mean_absolute_percentage_error(y_test, y_pred_lr)

print("Linear Regression MSE:", mse_lr)
print("Linear Regression MAPE:", mape_lr)
# Out:
# Linear Regression MSE: 21.517444231177297
# Linear Regression MAPE: 0.16521221680468381

# %%
# Import required libraries
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_squared_error, mean_absolute_percentage_error, r2_score
import numpy as np

# %%
# Initialize Random Forest Regressor model
rf = RandomForestRegressor(
    n_estimators=100,
    random_state=42
)

# %%
rf_model = rf.fit(X_train, y_train)

# %%
y_pred_rf = rf_model.predict(X_test)

# %%
# Calculate performance metrics for Random Forest model
mse_rf = mean_squared_error(y_test, y_pred_rf)
rmse_rf = np.sqrt(mse_rf)
mape_rf = mean_absolute_percentage_error(y_test, y_pred_rf)
r2_rf = r2_score(y_test, y_pred_rf)

print("Random Forest Results")
print("MSE:", mse_rf)
print("RMSE:", rmse_rf)
print("MAPE:", mape_rf)
print("R2 Score:", r2_rf)
# Out:
# Random Forest Results
# MSE: 9.619662013157892
# RMSE: 3.1015579977098433
# MAPE: 0.10856801497678763
# R2 Score: 0.8708997131330258

# %% [markdown]
# Conclusion
#
# This experiment demonstrates the application of machine learning in forecasting housing prices. It provides insight into the training of data and its utilization for predictions. This approach is valuable for addressing practical issues such as estimating real estate values.
#
#
# Author: Palak Salunkhe
